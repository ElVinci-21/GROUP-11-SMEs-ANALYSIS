# %%
print("Hello hermano")
# Out:
# Hello hermano

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
print("All libraries loaded successfully")
# Out:
# All libraries loaded successfully

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\MUCHAMI\OneDrive\Desktop\SME PROJECT

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '2025_Kenya_WBES_clean_columns MAIN.xlsx', 'SME PROJECT-Copy1.ipynb', 'SME PROJECT.ipynb', 'SME PROJECT.ipynb.invalid']

# %%
data =pd.read_excel("2025_Kenya_WBES_clean_columns MAIN.xlsx")

# %%
data.head()
# Out:
#   WEB STD FIRMID Firm ID Industry Sampling Sector Sampling Size  \
# 0          idstd      id                      a4a           a6a
# 1        1597844       1                     Food        Medium
# 2        1597845       4                     Food         Small
# 3        1597847       6                     Food        Medium
# 4        1597848       8                     Food        Medium
#
#   Sampling Region Sample Frame Level   Questionnaire  \
# 0              a2                a1c              a0
# 1     Rift Valley               Firm   Manufacturing
# 2     Rift Valley               Firm   Manufacturing
# 3           Coast               Firm  Other services
# 4     Rift Valley               Firm   Manufacturing
#
#   Region of The Establishment Screener Size Country Code  ...  \
# 0                         a3a           a6c           a1  ...
# 1                 Rift Valley            18           94  ...
# 2                 Rift Valley             5           94  ...
# ...

# %%
data.tail()
# Out:
#     WEB STD FIRMID Firm ID Industry Sampling Sector Sampling Size  \
# 828        1598862   16890             Construction         Small
# 829        1598864   16922           Other Services         Small
# 830        1598865   16925                   Retail         Small
# 831        1598866   16928             Construction        Medium
# 832        1598867   16951      Other Manufacturing        Medium
#
#            Sampling Region Sample Frame Level   Questionnaire  \
# 828  East and Northeastern               Firm  Other services
# 829                Nairobi               Firm  Other services
# 830                Nairobi               Firm  Other services
# 831                Central               Firm  Other services
# 832                Central               Firm   Manufacturing
#
#     Region of The Establishment Screener Size Country Code  ...  \
# 828       East and Northeastern            14           94  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 84 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   WEB STD FIRMID                                                                    833 non-null    object
#  1   Firm ID                                                                           833 non-null    object
#  2   Industry Sampling Sector                                                          833 non-null    str
#  3   Sampling Size                                                                     833 non-null    str
#  4   Sampling Region                                                                   833 non-null    str
#  5   Sample Frame Level                                                                833 non-null    str
# ...

# %%
data.describe()
# Out:
#        WEB STD FIRMID Firm ID Industry Sampling Sector Sampling Size  \
# count             833     833                      833           833
# unique            833     833                        8             3
# top             idstd      id           Other Services         Small
# freq                1       1                      152           499
#
#        Sampling Region Sample Frame Level   Questionnaire  \
# count              833                833             833
# unique               7                  2               4
# top            Nairobi               Firm  Other services
# freq               227                832             399
#
#        Region of The Establishment  Screener Size  Country Code  ...  \
# count                          833            833           833  ...
# unique                           7            116             2  ...
# top                        Nairobi              5            94  ...
# ...

# %%
data.isnull().sum()
# Out:
# WEB STD FIRMID                                        0
# Firm ID                                               0
# Industry Sampling Sector                              0
# Sampling Size                                         0
# Sampling Region                                       0
#                                                      ..
# Responses To The Questions About Figures AreÃ¢Â€Â¦    0
# Weight according to strict eligibility                0
# Weight according to median eligibility                0
# Weight according to weak eligibility                  0
# see notes                                             0
# Length: 84, dtype: int64

# %%
data.columns
# Out:
# Index(['WEB STD FIRMID', 'Firm ID', 'Industry Sampling Sector',
#        'Sampling Size', 'Sampling Region', 'Sample Frame Level',
#        'Questionnaire', 'Region of The Establishment', 'Screener Size',
#        'Country Code', 'Legal Status of The Firm', 'Other (Specify)',
#        'Is the largest owner also the top manager',
#        '% Owned By Private Domestic Individuals, Companies or organizations',
#        '% Owned By Government/State', 'Year Establishment Began Operations',
#        'Number of Full-Time Employees of The Establishment When It Started Operations',
#        'In What Year Was This Establishment Formally Registered?',
#        'Establishment Has Its Own Website',
#        'Application To Obtain Fixed Broadband Internet Connection Over The Last 2 Years',
#        'How Many Days Did It Take For You To Obtain Internet Connection?',
#        'Did You Experience Internet Disruptions In Last FY?',
#        'How difficult to switch internet providers?',
# ...

# %%
data.columns = data.columns.str.strip()

# %%
print("data.columns")
# Out:
# data.columns

# %%
for col in data.columns:
    print(col)
# Out:
# WEB STD FIRMID
# Firm ID
# Industry Sampling Sector
# Sampling Size
# Sampling Region
# Sample Frame Level
# Questionnaire
# Region of The Establishment
# Screener Size
# Country Code
# Legal Status of The Firm
# Other (Specify)
# Is the largest owner also the top manager
# % Owned By Private Domestic Individuals, Companies or organizations
# % Owned By Government/State
# Year Establishment Began Operations
# Number of Full-Time Employees of The Establishment When It Started Operations
# In What Year Was This Establishment Formally Registered?
# Establishment Has Its Own Website
# Application To Obtain Fixed Broadband Internet Connection Over The Last 2 Years
# How Many Days Did It Take For You To Obtain Internet Connection?
# Did You Experience Internet Disruptions In Last FY?
# How difficult to switch internet providers?
# Establishment'S Main Product/Service Last FY
# Main Product/Service: Percent of Total Annual Sales
# ...

# %%
data.dtypes
# Out:
# WEB STD FIRMID                                        object
# Firm ID                                               object
# Industry Sampling Sector                                 str
# Sampling Size                                            str
# Sampling Region                                          str
#                                                        ...
# Responses To The Questions About Figures AreÃ¢Â€Â¦       str
# Weight according to strict eligibility                object
# Weight according to median eligibility                object
# Weight according to weak eligibility                  object
# see notes                                             object
# Length: 84, dtype: object

# %%
data["In Last Fiscal Year, What Were This Establishment Total Annual Sales?"] = pd.to_numeric(
    data["In Last Fiscal Year, What Were This Establishment Total Annual Sales?"],
    errors="coerce"
)

data["Cost of Raw Materials And Intermediate Goods Used In Prod. In Last Fiscal Year"] = pd.to_numeric(
    data["Cost of Raw Materials And Intermediate Goods Used In Prod. In Last Fiscal Year"],
    errors="coerce"
)

# %%
data["profitability"] = (
    data["In Last Fiscal Year, What Were This Establishment Total Annual Sales?"]
    - data["Cost of Raw Materials And Intermediate Goods Used In Prod. In Last Fiscal Year"]
)

# %%
data[["profitability"]].head()
# Out:
#    profitability
# 0            NaN
# 1      1340000.0
# 2       700000.0
# 3            NaN
# 4     23294192.0

# %%
data[["profitability"]].head(11)
# Out:
#     profitability
# 0             NaN
# 1    1.340000e+06
# 2    7.000000e+05
# 3             NaN
# 4    2.329419e+07
# 5    3.200000e+06
# 6    4.020000e+09
# 7    1.700000e+07
# 8    1.150000e+07
# 9    7.320000e+07
# 10   2.050000e+07

# %%
pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
data[["profitability"]].head(11)
# Out:
#       profitability
# 0               NaN
# 1      1,340,000.00
# 2        700,000.00
# 3               NaN
# 4     23,294,192.00
# 5      3,200,000.00
# 6  4,020,000,000.00
# 7     17,000,000.00
# 8     11,500,000.00
# 9     73,200,000.00
# 10    20,500,000.00

# %%
data["profitability"].describe()
# Out:
# count               265.00
# mean        707,370,431.86
# std       7,420,550,430.12
# min             600,000.00
# 25%           9,600,000.00
# 50%          33,000,000.00
# 75%         150,000,000.00
# max     120,000,000,000.00
# Name: profitability, dtype: float64

# %%
import numpy as np

data["log_profitability"] = np.log(data["profitability"])

# %%
data["log_profitability"] = np.log(data["profitability"].replace(0, np.nan))

# %%
data["log_profitability"].describe()
# Out:
# count   265.00
# mean     17.50
# std       1.96
# min      13.30
# 25%      16.08
# 50%      17.31
# 75%      18.83
# max      25.51
# Name: log_profitability, dtype: float64

# %%
df = data.copy()

# %%
df["For The Most Recent Loan, What Was The Value At The Time of Approval?"].head()
# Out:
# 0          k11
# 1          NaN
# 2          NaN
# 3    100000000
# 4     10000000
# Name: For The Most Recent Loan, What Was The Value At The Time of Approval?, dtype: object

# %%
df["For The Most Recent Loan, What Was The Value At The Time of Approval?"].dtype
# Out:
# dtype('O')

# %%
df["loan amount"] = pd.to_numeric(
    df["For The Most Recent Loan, What Was The Value At The Time of Approval?"],
    errors="coerce"
)

# %%
df["loan amount"].describe()
# Out:
# count             397.00
# mean       22,494,220.65
# std        76,501,520.94
# min            30,000.00
# 25%         2,000,000.00
# 50%         5,000,000.00
# 75%        12,800,000.00
# max     1,200,000,000.00
# Name: loan amount, dtype: float64

# %%
df["loan amount"].head(11)
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3    100,000,000.00
# 4     10,000,000.00
# 5        300,000.00
# 6        600,000.00
# 7               NaN
# 8      8,000,000.00
# 9               NaN
# 10              NaN
# Name: loan amount, dtype: float64

# %%
df["log loan amount"] = np.log(df["loan amount"].replace(0, np.nan))

# %%
df["log loan amount"].describe()
# Out:
# count   397.00
# mean     15.46
# std       1.70
# min      10.31
# 25%      14.51
# 50%      15.42
# 75%      16.36
# max      20.91
# Name: log loan amount, dtype: float64

# %%
df = df.rename(columns={
    "log_profitability": "log profitability"
})

# %%
[col for col in df.columns if "log" in col.lower()]
# Out:
# ['log profitability', 'log loan amount']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(
    df["log loan amount"],
    df["log profitability"]
)

plt.xlabel("Log Loan Amount")
plt.ylabel("Log Profitability")
plt.title("Scatter Plot of Log Loan Amount vs Log Profitability")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(
    df["loan amount"],
    df["profitability"]
)

plt.xlabel("Loan Amount")
plt.ylabel("Profitability")
plt.title("Raw Scatter Plot: Loan Amount vs Profitability")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

sns.regplot(
    x="log loan amount",
    y="log profitability",
    data=df
)

plt.title("Regression Line: Log Profitability vs Log Loan Amount")
plt.show()

# %%
df["log loan amount"].corr(df["log profitability"])
# Out:
# np.float64(0.5991665254255708)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(
    df["log loan amount"],
    df["profitability"]
)

plt.xlabel("Log Loan Amount")
plt.ylabel("Profitability")
plt.title("Scatter Plot of Profitability vs Log Loan Amount")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(
    df["loan amount"],
    df["log profitability"]
)

plt.xlabel("Loan Amount")
plt.ylabel("Log Profitability")
plt.title("Scatter Plot of Log Profitability vs Loan Amount")

plt.show()

# %%
current_year = 2025

df["firm age"] = current_year - pd.to_numeric(
    df["Year Establishment Began Operations"],
    errors="coerce"
)

# %%
df[["firm age"]].head(11)
# Out:
#     firm age
# 0        NaN
# 1      33.00
# 2      20.00
# 3      30.00
# 4      23.00
# 5      80.00
# 6      33.00
# 7      13.00
# 8      12.00
# 9       7.00
# 10     37.00

# %%
df["firm age"].describe()
# Out:
# count   832.00
# mean     19.84
# std      15.63
# min       1.00
# 25%      10.00
# 50%      15.00
# 75%      26.00
# max     129.00
# Name: firm age, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(
    df["firm age"],
    df["profitability"]
)

plt.xlabel("Firm Age")
plt.ylabel("Profitability")
plt.title("Scatter Plot of Profitability vs Firm age")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

plt.scatter(
    df["firm age"],
    df["log profitability"]
)

plt.xlabel("Firm Age")
plt.ylabel("Log Profitability")
plt.title("Scatter Plot of Log Profitability vs Firm age")

plt.show()

# %%
import numpy as np

df["log firm age"] = np.log(df["firm age"])

# %%
df[["firm age", "log firm age"]].head()
# Out:
#    firm age  log firm age
# 0       NaN           NaN
# 1     33.00          3.50
# 2     20.00          3.00
# 3     30.00          3.40
# 4     23.00          3.14

# %%
df[["firm age", "log firm age"]].head(11)
# Out:
#     firm age  log firm age
# 0        NaN           NaN
# 1      33.00          3.50
# 2      20.00          3.00
# 3      30.00          3.40
# 4      23.00          3.14
# 5      80.00          4.38
# 6      33.00          3.50
# 7      13.00          2.56
# 8      12.00          2.48
# 9       7.00          1.95
# 10     37.00          3.61

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(
    df["log firm age"],
    df["log profitability"]
)

plt.xlabel("Log Firm Age")
plt.ylabel("Log Profitability")
plt.title("Scatter Plot of Log Profitability vs Log firm age")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

sns.regplot(
    x="log firm age",
    y="log profitability",
    data=df
)

plt.xlabel("Log Firm Age")
plt.ylabel("Log Profitability")
plt.title("Regression Line: Log Profitability  vs LOg Firm Age")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

sns.regplot(
    x="firm age",
    y="log profitability",
    data=df
)

plt.xlabel("Firm Age")
plt.ylabel("Log Profitability")
plt.title("Regression Line: Log Profitability vs Firm Age")

plt.show()

# %%
df["log firm age"].corr(df["log profitability"])
# Out:
# np.float64(0.22043080494125297)

# %%
df["firm age"].corr(df["log profitability"])
# Out:
# np.float64(0.19631227174225932)

# %%
df["tax rate"] = pd.to_numeric(
    df["Effective income-based tax rate"],
    errors="coerce"
)

# %%
df[["tax rate"]].head(11)
# Out:
#     tax rate
# 0        NaN
# 1        NaN
# 2      16.00
# 3      18.00
# 4       6.00
# 5      13.00
# 6      10.00
# 7      14.00
# 8      25.00
# 9      10.00
# 10     10.00

# %%
df["tax rate"].describe()
# Out:
# count   825.00
# mean     17.70
# std       9.39
# min       0.00
# 25%      10.00
# 50%      16.00
# 75%      25.00
# max      50.00
# Name: tax rate, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

sns.regplot(
    x="tax rate",
    y="log profitability",
    data=df
)

plt.xlabel("Tax Rate (%)")
plt.ylabel("Log Profitability")
plt.title("Log Profitability vs Tax Rate")

plt.show()

# %%
df["tax rate"].corr(df["log profitability"])
# Out:
# np.float64(0.1594917307760317)

# %%
df["employees"] = pd.to_numeric(
    df["Num. Permanent, Full-Time Employees At End of Last Fiscal Year"],
    errors="coerce"
)

# %%
df[["employees"]].head(11)
# Out:
#     employees
# 0         NaN
# 1       18.00
# 2        5.00
# 3       84.00
# 4       10.00
# 5        5.00
# 6      180.00
# 7       20.00
# 8       14.00
# 9       45.00
# 10      91.00

# %%
df["employees"].describe()
# Out:
# count     832.00
# mean       32.59
# std        59.05
# min         1.00
# 25%         8.00
# 50%        15.00
# 75%        35.00
# max     1,000.00
# Name: employees, dtype: float64

# %%
plt.figure(figsize=(8, 6))

sns.regplot(
    x='employees',
    y='log profitability',
    data=df
)

plt.xlabel("Number of Employees")
plt.ylabel("Log Profitability")
plt.title("Log Profitability vs Number of Employees")

plt.show()

# %%
df["log employees"] = np.log(df["employees"].replace(0, np.nan))

# %%
df[["log employees"]].head(11)
# Out:
#     log employees
# 0             NaN
# 1            2.89
# 2            1.61
# 3            4.43
# 4            2.30
# 5            1.61
# 6            5.19
# 7            3.00
# 8            2.64
# 9            3.81
# 10           4.51

# %%
df["log employees"].describe()
# Out:
# count   832.00
# mean      2.86
# std       1.04
# min       0.00
# 25%       2.08
# 50%       2.71
# 75%       3.56
# max       6.91
# Name: log employees, dtype: float64

# %%
plt.figure(figsize=(8, 6))

sns.regplot(
    x='log employees',
    y='log profitability',
    data=df
)

plt.xlabel("Log Number of Employees")
plt.ylabel("Log Profitability")
plt.title("Log Profitability vs Log Number of Employees")

plt.show()

# %%
df["log employees"].corr(df["log profitability"])
# Out:
# np.float64(0.6714970384246263)

# %%
#CORRELATION BETWEEN INDEPENDENT VARIABLES
df[[
    "log loan amount",
    "log firm age",
    "tax rate",
    "log employees"
]].corr()
# Out:
#                  log loan amount  log firm age  tax rate  log employees
# log loan amount             1.00          0.15      0.13           0.50
# log firm age                0.15          1.00      0.06           0.25
# tax rate                    0.13          0.06      1.00           0.07
# log employees               0.50          0.25      0.07           1.00

# %%
#CLEANING REGRESSION DATA TO REMOVE NAN VALUES AND EMPTY CELLS
regression_data = df[[
    "log profitability",
    "log loan amount",
    "log firm age",
    "tax rate",
    "log employees"
]].dropna()

# %%
#DEFINING X
X = regression_data[[
    "log loan amount",
    "log firm age",
    "tax rate",
    "log employees"
]]

# %%
#DEFINING Y
y = regression_data["log profitability"]

# %%
#ADDING CONSTANT
X = sm.add_constant(X)

# %%
#FITTING THE MODEL
model = sm.OLS(y, X).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      log profitability   R-squared:                       0.590
# Model:                            OLS   Adj. R-squared:                  0.576
# Method:                 Least Squares   F-statistic:                     42.38
# Date:                Tue, 26 May 2026   Prob (F-statistic):           5.41e-22
# Time:                        04:13:13   Log-Likelihood:                -211.55
# No. Observations:                 123   AIC:                             433.1
# Df Residuals:                     118   BIC:                             447.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               8.2385      1.135      7.256      0.000       5.990      10.487
# ...
